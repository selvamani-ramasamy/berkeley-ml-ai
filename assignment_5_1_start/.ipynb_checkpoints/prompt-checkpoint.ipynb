# %% [markdown]
# ### Will a Customer Accept the Coupon?
#
# **Context**
#
# Imagine driving through town and a coupon is delivered to your cell phone for a restaraunt near where you are driving. Would you accept that coupon and take a short detour to the restaraunt? Would you accept the coupon but use it on a sunbsequent trip? Would you ignore the coupon entirely? What if the coupon was for a bar instead of a restaraunt? What about a coffee house? Would you accept a bar coupon with a minor passenger in the car? What about if it was just you and your partner in the car? Would weather impact the rate of acceptance? What about the time of day?
#
# Obviously, proximity to the business is a factor on whether the coupon is delivered to the driver or not, but what are the factors that determine whether a driver accepts the coupon once it is delivered to them? How would you determine whether a driver is likely to accept a coupon?
#
# **Overview**
#
# The goal of this project is to use what you know about visualizations and probability distributions to distinguish between customers who accepted a driving coupon versus those that did not.
#
# **Data**
#
# This data comes to us from the UCI Machine Learning repository and was collected via a survey on Amazon Mechanical Turk. The survey describes different driving scenarios including the destination, current time, weather, passenger, etc., and then ask the person whether he will accept the coupon if he is the driver. Answers that the user will drive there ‘right away’ or ‘later before the coupon expires’ are labeled as ‘Y = 1’ and answers ‘no, I do not want the coupon’ are labeled as ‘Y = 0’.  There are five different types of coupons -- less expensive restaurants (under \\$20), coffee houses, carry out & take away, bar, and more expensive restaurants (\\$20 - \\$50).

# %% [markdown]
# **Deliverables**
#
# Your final product should be a brief report that highlights the differences between customers who did and did not accept the coupons.  To explore the data you will utilize your knowledge of plotting, statistical summaries, and visualization using Python. You will publish your findings in a public facing github repository as your first portfolio piece.

# %% [markdown]
# ### Data Description
# Keep in mind that these values mentioned below are average values.
#
# The attributes of this data set include:
# 1. User attributes
#     -  Gender: male, female
#     -  Age: below 21, 21 to 25, 26 to 30, etc.
#     -  Marital Status: single, married partner, unmarried partner, or widowed
#     -  Number of children: 0, 1, or more than 1
#     -  Education: high school, bachelors degree, associates degree, or graduate degree
#     -  Occupation: architecture & engineering, business & financial, etc.
#     -  Annual income: less than \\$12500, \\$12500 - \\$24999, \\$25000 - \\$37499, etc.
#     -  Number of times that he/she goes to a bar: 0, less than 1, 1 to 3, 4 to 8 or greater than 8
#     -  Number of times that he/she buys takeaway food: 0, less than 1, 1 to 3, 4 to 8 or greater
#     than 8
#     -  Number of times that he/she goes to a coffee house: 0, less than 1, 1 to 3, 4 to 8 or
#     greater than 8
#     -  Number of times that he/she eats at a restaurant with average expense less than \\$20 per
#     person: 0, less than 1, 1 to 3, 4 to 8 or greater than 8
#     -  Number of times that he/she goes to a bar: 0, less than 1, 1 to 3, 4 to 8 or greater than 8
#
#
# 2. Contextual attributes
#     - Driving destination: home, work, or no urgent destination
#     - Location of user, coupon and destination: we provide a map to show the geographical
#     location of the user, destination, and the venue, and we mark the distance between each
#     two places with time of driving. The user can see whether the venue is in the same
#     direction as the destination.
#     - Weather: sunny, rainy, or snowy
#     - Temperature: 30F, 55F, or 80F
#     - Time: 10AM, 2PM, or 6PM
#     - Passenger: alone, partner, kid(s), or friend(s)
#
#
# 3. Coupon attributes
#     - time before it expires: 2 hours or one day

# %%
import itertools
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import math
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Problems
#
# Use the prompts below to get started with your data analysis.
#
# 1. Read in the `coupons.csv` file.

# %%
data = pd.read_csv('data/coupons.csv')

# %%
data.head()
# Out:
#        destination  passanger weather  temperature  time  \
# 0  No Urgent Place      Alone   Sunny           55   2PM
# 1  No Urgent Place  Friend(s)   Sunny           80  10AM
# 2  No Urgent Place  Friend(s)   Sunny           80  10AM
# 3  No Urgent Place  Friend(s)   Sunny           80   2PM
# 4  No Urgent Place  Friend(s)   Sunny           80   2PM
#
#                   coupon expiration  gender age      maritalStatus  ...  \
# 0        Restaurant(<20)         1d  Female  21  Unmarried partner  ...
# 1           Coffee House         2h  Female  21  Unmarried partner  ...
# 2  Carry out & Take away         2h  Female  21  Unmarried partner  ...
# 3           Coffee House         2h  Female  21  Unmarried partner  ...
# 4           Coffee House         1d  Female  21  Unmarried partner  ...
#
#    CoffeeHouse CarryAway RestaurantLessThan20 Restaurant20To50  \
# 0        never       NaN                  4~8              1~3
# ...

# %% [markdown]
# 2. Investigate the dataset for missing or problematic data.

# %%
na_counts = data.isna().sum().sort_values(ascending=False).reset_index(name='na_counts')
na_columns = na_counts[na_counts['na_counts'] > 0]
na_columns_list = na_columns['index'].to_list()
print(f"Columns with NA Values: {na_columns_list}\n")
print(na_columns)
# Out:
# Columns with NA Values: ['car', 'CoffeeHouse', 'Restaurant20To50', 'CarryAway', 'RestaurantLessThan20', 'Bar']
#
#                   index  na_counts
# 0                   car      12576
# 1           CoffeeHouse        217
# 2      Restaurant20To50        189
# 3             CarryAway        151
# 4  RestaurantLessThan20        130
# 5                   Bar        107

# %% [markdown]
# 3. Decide what to do about your missing data -- drop, replace, other...

# %%
# If there are incomplete records, it may be a negligible number.
# Consider maximum 5% NA to be usable in major analysis.
# Consider using invalid columns for minor analysis.
# Any column with greater than 5% NA will be dropped.
# One column is named incorrectly. ('passanger')
# Temperature data manipulation for later charting
# major_data.groupby(['direction_same', 'direction_opp']).size()
# ['direction_same', 'direction_opp'] are combined to form a single column
# ['toCoupon_GEQ5min', 'toCoupon_GEQ15min', 'toCoupon_GEQ25min'] can be combined into one column
max_allowable_na_records = 0.05 * data.shape[0]

data.rename(columns={'passanger': 'passenger'}, inplace=True)

data['temperature_feels_like'] = data['temperature'].apply(lambda x: 'cold (30F)' if x==30 else 'cool (55F)' if x==55 else 'warm (80F)' if x==80 else None)
data['direction'] = data.apply(lambda x: 'same' if x['direction_same']==1 else 'opposite', axis=1)
data['distance_to_deal'] = data.apply(lambda x: '25 or more' if x['toCoupon_GEQ25min']==1 else '15 or more' if x['toCoupon_GEQ15min']==1 else '5 or more' if x['toCoupon_GEQ5min']==1 else 'less than 5', axis=1)

cols_to_drop = {}
for col in na_columns_list:
      na_counts_this_col = na_columns.loc[na_columns['index']==col, 'na_counts'].values[0]
      if na_counts_this_col > max_allowable_na_records:
            cols_to_drop[col] = na_counts_this_col
cols_to_drop['temperature'] = None
cols_to_drop['direction_same'] = None
cols_to_drop['direction_opp'] = None
cols_to_drop['toCoupon_GEQ5min'] = None
cols_to_drop['toCoupon_GEQ15min'] = None
cols_to_drop['toCoupon_GEQ25min'] = None
print(f"Columns to drop:"
      f"\n\t{[(col, val) for col, val in cols_to_drop.items()]}")

major_data = data.copy().drop(cols_to_drop.keys(), axis=1)
major_data.dropna(inplace=True)

print(f"Dropped\n\t\tColumn(s)\t\tRow(s)"
      f"\n\t\t{len(cols_to_drop)} [{1-major_data.shape[1]/data.shape[1]:.1%}]\t\t{data.shape[0] - major_data.shape[0]} [{1-major_data.shape[0]/data.shape[0]:.1%}]")
# Out:
# Columns to drop:
# 	[('car', 12576), ('temperature', None), ('direction_same', None), ('direction_opp', None), ('toCoupon_GEQ5min', None), ('toCoupon_GEQ15min', None), ('toCoupon_GEQ25min', None)]
# Dropped
# 		Column(s)		Row(s)
# 		7 [24.1%]		605 [4.8%]

# %% [markdown]
# 4. What proportion of the total observations chose to accept the coupon?

# %%
def get_acceptance_rate(df, column=None, suppress_warning=False):
      try:
            sizes = df.groupby('Y').size()
            pct = sizes[1] / (sizes.sum())
      except KeyError:
            if not suppress_warning:
                  print(f"\nWarning in recent call `get_acceptance_rate`: Seems to be no positive records\nColumn Passed: {column}")
            pct = 0.0
      return pct

data_accepted_pct = get_acceptance_rate(data)
major_data_accepted_pct = get_acceptance_rate(major_data)

print(f"Proportions - Coupon Acceptance"
      f"\n\tAcceptance (All Data):\t\t{data_accepted_pct:.1%}"
      f"\n\tAcceptance (Selected Data):\t{major_data_accepted_pct:.1%}")
# Out:
# Proportions - Coupon Acceptance
# 	Acceptance (All Data):		56.8%
# 	Acceptance (Selected Data):	56.9%

# %% [markdown]
# 5. Use a bar plot to visualize the `coupon` column.

# %%
coupons_hist = sns.histplot(data=major_data, x='coupon')
coupons_hist.set_xticklabels(coupons_hist.get_xticklabels(), rotation=45, horizontalalignment='right')
# Out:
# [Text(0, 0, 'Restaurant(<20)'),
#  Text(1, 0, 'Coffee House'),
#  Text(2, 0, 'Bar'),
#  Text(3, 0, 'Carry out & Take away'),
#  Text(4, 0, 'Restaurant(20-50)')]

# %% [markdown]
# 6. Use a histogram to visualize the temperature column.

# %%
print(f"COUNTS:\n{major_data.groupby('temperature_feels_like')['Y'].count()}")
temperature_hist = sns.histplot(data=major_data, x='temperature_feels_like', hue='Y', multiple='fill')
temperature_hist.set_xticklabels(temperature_hist.get_xticklabels(), rotation=25, horizontalalignment='right')
# Out:
# COUNTS:
# temperature_feels_like
# cold (30F)    2195
# cool (55F)    3662
# warm (80F)    6222
# Name: Y, dtype: int64
# [Text(0, 0, 'cool (55F)'), Text(1, 0, 'warm (80F)'), Text(2, 0, 'cold (30F)')]

# %% [markdown]
# **Investigating the Bar Coupons**
#
# Now, we will lead you through an exploration of just the bar related coupons.
#
# 1. Create a new `DataFrame` that contains just the bar coupons.

# %%
bar_coupons = major_data.query('coupon == "Bar"')
bar_coupons.head()
# Out:
#         destination  passenger weather  time coupon expiration gender age  \
# 24  No Urgent Place  Friend(s)   Sunny  10AM    Bar         1d   Male  21
# 35             Home      Alone   Sunny   6PM    Bar         1d   Male  21
# 39             Work      Alone   Sunny   7AM    Bar         1d   Male  21
# 46  No Urgent Place  Friend(s)   Sunny  10AM    Bar         1d   Male  46
# 57             Home      Alone   Sunny   6PM    Bar         1d   Male  46
#
#    maritalStatus  has_children  ...           income    Bar CoffeeHouse  \
# 24        Single             0  ...  $62500 - $74999  never       less1
# 35        Single             0  ...  $62500 - $74999  never       less1
# 39        Single             0  ...  $62500 - $74999  never       less1
# 46        Single             0  ...  $12500 - $24999  never         4~8
# 57        Single             0  ...  $12500 - $24999  never         4~8
#
#    CarryAway RestaurantLessThan20 Restaurant20To50  Y temperature_feels_like  \
# ...

# %% [markdown]
# 2. What proportion of bar coupons were accepted?

# %%
bar_coupons_accepted_pct = get_acceptance_rate(bar_coupons)
print(f"Proportions - Coupon Acceptance (Bar Coupons, Major Data)"
      f"\n\n\tAcceptance:\t\t{bar_coupons_accepted_pct:.1%}")
# Out:
# Proportions - Coupon Acceptance (Bar Coupons, Major Data)
#
# 	Acceptance:		41.2%

# %% [markdown]
# 3. Compare the acceptance rate between those who went to a bar 3 or fewer times a month to those who went more.

# %%
high_freq = 'Bar in ("gt8", "4~8")'
low_freq = high_freq.replace('in', 'not in')


bar_high_freq = get_acceptance_rate(bar_coupons.query(high_freq))
bar_low_freq = get_acceptance_rate(bar_coupons.query(low_freq))
print(f"Proportions - Coupon Acceptance (Bar Coupons, Major Data)"
      f"\n\nFrequency visiting bars"
      f"\n\tHigh:\t\t{bar_high_freq:.1%}"
      f"\n\tLow:\t\t{bar_low_freq:.1%}"
      )
# Out:
# Proportions - Coupon Acceptance (Bar Coupons, Major Data)
#
# Frequency visiting bars
# 	High:		76.2%
# 	Low:		37.3%

# %% [markdown]
# 4. Compare the acceptance rate between drivers who go to a bar more than once a month and are over the age of 25 to the all others.  Is there a difference?

# %%
over_25 = 'age not in ("below21", "21")'
bar_gt_1pm = 'Bar not in ("never", "less1")'
isolated_pop_query = f'{over_25} and {bar_gt_1pm}'

bar_regular_over_25 = get_acceptance_rate(bar_coupons.query(isolated_pop_query))
other_population = get_acceptance_rate(bar_coupons.query(isolated_pop_query.replace("not in", "in")))

print(f"Proportions - Coupon Acceptance (Bar Coupons, Major Data)"
      f"\n\nAge > 25 and Bar Visits Per Month > 1"
      f"\n\tTrue:\t\t{bar_regular_over_25:.1%}"
      f"\n\tFalse:\t\t{other_population:.1%}"
      )
# Out:
# Proportions - Coupon Acceptance (Bar Coupons, Major Data)
#
# Age > 25 and Bar Visits Per Month > 1
# 	True:		69.0%
# 	False:		38.8%

# %% [markdown]
# 5. Use the same process to compare the acceptance rate between drivers who go to bars more than once a month and had passengers that were not a kid and had occupations other than farming, fishing, or forestry.

# %%
passenger_not_child = 'passenger not in ("Kid(s)")'
not_farm_fish_forest = 'occupation not in ("Farming Fishing & Forestry")'
isolated_pop_query = f'{bar_gt_1pm} and {passenger_not_child} and {not_farm_fish_forest}'

bar_regular_no_child_no_fff = get_acceptance_rate(bar_coupons.query(isolated_pop_query))
other_population = get_acceptance_rate(bar_coupons.query(isolated_pop_query.replace("not in", "in")))

print(f"Proportions - Coupon Acceptance (Bar Coupons, Major Data)"
      f"\n\nBar Visits Per Month > 1 and Passenger not Kid(s) and Occupation not FF&F"
      f"\n\tTrue:\t\t{bar_regular_no_child_no_fff:.1%}"
      f"\n\tFalse:\t\t{other_population:.1%}"
      )
# Out:
# Proportions - Coupon Acceptance (Bar Coupons, Major Data)
#
# Bar Visits Per Month > 1 and Passenger not Kid(s) and Occupation not FF&F
# 	True:		70.9%
# 	False:		33.3%

# %% [markdown]
# 6. Compare the acceptance rates between those drivers who:
#
# - go to bars more than once a month, had passengers that were not a kid, and were not widowed *OR*
# - go to bars more than once a month and are under the age of 30 *OR*
# - go to cheap restaurants more than 4 times a month and income is less than 50K.

# %%
not_widowed = 'maritalStatus not in ("Widowed")'
age_under_30 = 'age not in ("31", "36", "41", "46", "50plus")'
cheap_resto_gt4pm = 'RestaurantLessThan20 not in ("never", "less1", "1~3")'
income_lt_50k = 'income not in ("$100000 or More", "$50000 - $62499", "$62500 - $74999", "$75000 - $87499", "$87500 - $99999")'

isolation_1 = f'{bar_gt_1pm} and {passenger_not_child} and {not_widowed}'
isolation_2 = f'{bar_gt_1pm} and {age_under_30}'
isolation_3 = f'{cheap_resto_gt4pm} and {income_lt_50k}'
isolated_pop_query = f'{isolation_1} and {age_under_30} and {isolation_3}'

bar_regular_no_child_no_widow = get_acceptance_rate(bar_coupons.query(isolation_1))
bar_regular_under_30 = get_acceptance_rate(bar_coupons.query(isolation_2))
cheap_resto_regular_income_lt_50k = get_acceptance_rate(bar_coupons.query(isolation_3))

anti_isolation_1 = get_acceptance_rate(bar_coupons.query(isolation_1.replace("not in", "in")))
anti_isolation_2 = get_acceptance_rate(bar_coupons.query(isolation_2.replace("not in", "in")))
anti_isolation_3 = get_acceptance_rate(bar_coupons.query(isolation_3.replace("not in", "in")))

all_criteria_true = get_acceptance_rate(bar_coupons.query(isolated_pop_query))
all_criteria_false = get_acceptance_rate(bar_coupons[~(bar_coupons.index.isin(bar_coupons.query(isolated_pop_query).index))])

print(f"Proportions - Coupon Acceptance (Bar Coupons, Major Data)"
      f"\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tMatch\t\tNo Match"
      f"\n\nBar Visits Per Month > 1 and Passenger not Kid(s) and Not Widowed:"
      f"\t{bar_regular_no_child_no_widow:.1%}\t\t{anti_isolation_1:.1%}"
      f"\n\nBar Visits Per Month > 1 and Age < 30:"
      f"\t\t\t\t\t\t\t\t{bar_regular_under_30:.1%}\t\t{anti_isolation_2:.1%}"
      f"\n\nCheap Resto > 4 per month and Income < 50k:"
      f"\t\t\t\t\t\t\t{cheap_resto_regular_income_lt_50k:.1%}\t\t{anti_isolation_3:.1%}"
      f"\n\nAll Above Criteria Combined:"
      f"\t\t\t\t\t\t\t\t\t\t{all_criteria_true:.1%}\t\t{all_criteria_false:.1%}"
      )
# Out:
# Warning in recent call `get_acceptance_rate`: Seems to be no positive records
# Column Passed: None
# Proportions - Coupon Acceptance (Bar Coupons, Major Data)
#
# 																	Match		No Match
#
# Bar Visits Per Month > 1 and Passenger not Kid(s) and Not Widowed:	70.9%		0.0%
#
# Bar Visits Per Month > 1 and Age < 30:								72.0%		26.6%
#
# Cheap Resto > 4 per month and Income < 50k:							45.6%		39.6%
#
# All Above Criteria Combined:										75.8%		39.5%

# %% [markdown]
# 7.  Based on these observations, what do you hypothesize about drivers who accepted the bar coupons?

# %% [markdown]
# # Response to #7
#
# ## Insights
# `Bar` coupons were:
# - offered `fourth-most` (second-least) frequently
# - offered `most frequently` on warm `(80F)` days
# - accepted `most frequently` on warm `(80F)` days
# - accepted `less frequently (41.2%)` than the `aggregate (56.9%)`
# - accepted by `frequent bar-goers` more frequently `(76.2%)` compared to the rest of the `Bar` coupon population `(37.3%)`
# - accepted more frequently by regular bar-goers over 25 years old `(69.0%)` compared to the rest of the `Bar` coupon population `(38.8%)`
# - accepted more frequently by regular bar-goers driving without children and who don't work in FF&F occupations `(70.9%)` compared to the rest of the `Bar` coupon population `(33.3%)`
# - visiting bars more than once per month seems to be a good indicator of acceptance
#       - `Bar Visits Per Month > 1` combined with `Age > 25` or with `Age < 30` has nearly identical acceptance `(69.0% vs 72.0%)`
# - the `Cheap Resto > 4 per month and Income < 50k` population is not strongly indicative of acceptance `(45.6% vs 39.6%)`
# - the `Cheap Resto > 4 per month and Income < 50k` population accepts coupons slightly more frequently than the overall `Bar` population `(45.6% vs 41.2%)`
# ## Summary
# `What do you hypothesize about drivers who accepted the bar coupons?`
#
# Drivers who vist bars greater than 3 times per month were much more likely to accept coupons for bars `(76.2%)`. Drivers visiting bars 1-3 times per month also accepted much more frequently `(64.6%)` than the aggregate Bar coupon population. Warm weather (80F) appears to be slightly indicative of accepting a coupon in the aggregate population, but it appears to be a relatively weak indicator for Bar coupons specifically. Cool weather (55F) appears to be over-represented in the Bar coupon population compared to the aggregate population, which is dominated by Warm weather (80F). Based on this preliminary analysis, it appears Amazon should focus marketing efforts for Bar coupons on those individuals visiting a bar once per month or more.

# %% [markdown]
# ### Independent Investigation
#
# Using the bar coupon example as motivation, you are to explore one of the other coupon groups and try to determine the characteristics of passengers who accept the coupons.

# %% [markdown]
# ## Independent Investigation - Coupon Choice: Coffee House
# ### Motivation:
# Coffee House coupons are offered the most frequently in the dataset so should be relatively rich.

# %%
coffee_house_coupons = major_data.query('coupon=="Coffee House"')
coffee_house_coupons.head()
# Out:
#         destination  passenger weather  time        coupon expiration gender  \
# 23  No Urgent Place  Friend(s)   Sunny  10AM  Coffee House         2h   Male
# 26  No Urgent Place  Friend(s)   Sunny   2PM  Coffee House         1d   Male
# 27  No Urgent Place  Friend(s)   Sunny   2PM  Coffee House         2h   Male
# 28  No Urgent Place  Friend(s)   Sunny   2PM  Coffee House         1d   Male
# 30  No Urgent Place  Friend(s)   Sunny   6PM  Coffee House         2h   Male
#
#    age maritalStatus  has_children  ...           income    Bar CoffeeHouse  \
# 23  21        Single             0  ...  $62500 - $74999  never       less1
# 26  21        Single             0  ...  $62500 - $74999  never       less1
# 27  21        Single             0  ...  $62500 - $74999  never       less1
# 28  21        Single             0  ...  $62500 - $74999  never       less1
# 30  21        Single             0  ...  $62500 - $74999  never       less1
#
# ...

# %%
def get_interesting_histograms(histdata, cols_of_interest, stat='count', figsize=(12, 16),  rot=25, multiple='layer', kde=False):
      num_cols = len(cols_of_interest)
      num_fig_rows = math.ceil(num_cols/3) if num_cols >= 3 else 1
      num_fig_cols = 3 if num_cols >= 3 else num_cols
      fig, axs = plt.subplots(num_fig_rows, num_fig_cols, figsize=figsize)
      i=0
      for row in range(num_fig_rows):
            column_range = range(3) if num_cols >= 3 else range(num_cols)
            for column in column_range:
                  if num_fig_rows == 1 and num_fig_cols == 1:
                        ax = axs
                  elif num_fig_rows == 1:
                        ax = axs[column]
                  else:
                        ax = axs[row, column]
                  sns.histplot(data=histdata, x=cols_of_interest[i], hue='Y', ax=ax, multiple=multiple, stat=stat, kde=kde)
                  ax.set_xticklabels(ax.get_xticklabels(), rotation=rot, horizontalalignment='right')
                  i += 1
      fig.tight_layout()

set_1_cols_of_interest = ['distance_to_deal', 'destination', 'distance_to_deal', 'direction',
                          'passenger', 'weather', 'temperature_feels_like', 'time', 'expiration']

set_2_cols_of_interest = [
                          'gender', 'age', 'maritalStatus', 'has_children',
                          'Bar', 'CoffeeHouse', 'CarryAway',
                          'RestaurantLessThan20', 'Restaurant20To50']

set_3_cols_of_interest = [ 'income', 'education', 'occupation', ]

get_interesting_histograms(coffee_house_coupons, ['coupon'], multiple='dodge', figsize=(4, 4))
print(f"Coffee House Coupons: Acceptance Rates\n{coffee_house_coupons.groupby('Y').size() / coffee_house_coupons.groupby('Y').size().sum()}")
# Out:
# Coffee House Coupons: Acceptance Rates
# Y
# 0    0.503669
# 1    0.496331
# dtype: float64

# %%
print(f"Charting {set_1_cols_of_interest}")
get_interesting_histograms(coffee_house_coupons, set_1_cols_of_interest)
# Out:
# Charting ['distance_to_deal', 'destination', 'distance_to_deal', 'direction', 'passenger', 'weather', 'temperature_feels_like', 'time', 'expiration']

# %%
print(f"Charting {set_2_cols_of_interest}")
get_interesting_histograms(coffee_house_coupons, set_2_cols_of_interest)
# Out:
# Charting ['gender', 'age', 'maritalStatus', 'has_children', 'Bar', 'CoffeeHouse', 'CarryAway', 'RestaurantLessThan20', 'Restaurant20To50']

# %%
print(f"Charting {set_3_cols_of_interest}")
get_interesting_histograms(coffee_house_coupons, set_3_cols_of_interest, figsize=(24, 10), rot=70, multiple='layer')
# Out:
# Charting ['income', 'education', 'occupation']

# %%
print(f"Charting {set_3_cols_of_interest}")
get_interesting_histograms(coffee_house_coupons, set_3_cols_of_interest, figsize=(24, 10), rot=70, multiple='fill')
# Out:
# Charting ['income', 'education', 'occupation']

# %%
# want to maximize % Y
def find_col_max_accept_rate(dat, column, suppress_warnings=False):
      max_accept_name = ''
      max_accept_pct = 0.0
      for val in dat[column].unique():
            rate = get_acceptance_rate(dat.loc[dat[column]==val], column, suppress_warning=suppress_warnings)
            if rate > max_accept_pct:
                  max_accept_pct = rate
                  max_accept_name = val
      return max_accept_name, max_accept_pct

# %%
def print_quick_data(column, column_value, pct_accept, min_colon_loc=25, min_float_loc=45, column2=None, column_value2=None, pct_accept2=None):
      colon_loc = min_colon_loc - len(column) - len(column2) if column2 else min_colon_loc - len(column)
      float_loc = min_float_loc - len(str(column_value)) - len(str(column_value2)) if column2 else min_float_loc - len(str(column_value))
      print(f"{column}{f' + {column2}' if column2 else ''}"
            f"{'.' * colon_loc}"
            f"  {column_value}{f' + {column_value2}' if column_value2 else ''}"
            f"{'.' * float_loc}"
            f"  {f'{pct_accept:.1%} --> {pct_accept2:.1%}' if pct_accept2 else f'{pct_accept:.1%}'}")

set_all_of_interest = set(set_1_cols_of_interest + set_2_cols_of_interest + set_3_cols_of_interest)

for col in set_all_of_interest:
      name, pct = find_col_max_accept_rate(coffee_house_coupons, col)
      print_quick_data(col, name, pct)
# Out:
# CoffeeHouse..............  4~8..........................................  68.2%
# time.....................  10AM.........................................  63.5%
# distance_to_deal.........  5 or more....................................  54.5%
# CarryAway................  1~3..........................................  50.9%
# education................  Some High School.............................  60.7%
# temperature_feels_like...  warm (80F)...................................  52.7%
# expiration...............  1d...........................................  58.1%
# Restaurant20To50.........  gt8..........................................  63.7%
# passenger................  Friend(s)....................................  59.7%
# Bar......................  4~8..........................................  52.2%
# age......................  below21......................................  67.8%
# RestaurantLessThan20.....  gt8..........................................  52.2%
# ...

# %%
for col_primary in set_all_of_interest:
      name, pct = find_col_max_accept_rate(coffee_house_coupons, col_primary)
      filt = (coffee_house_coupons[col_primary]==name)
      filt_data = coffee_house_coupons.loc[filt]
      for col_secondary in set_all_of_interest:
            name2, pct2 = find_col_max_accept_rate(filt_data, col_secondary, suppress_warnings=True)
      print_quick_data(col_primary, name, pct, column2=col_secondary, column_value2=name2, min_colon_loc=40, pct_accept2=pct2)
# Out:
# CoffeeHouse + occupation...................  4~8 + Office & Administrative Support...........  68.2% --> 100.0%
# time + occupation..........................  10AM + Building & Grounds Cleaning & Maintenance  63.5% --> 100.0%
# distance_to_deal + occupation..............  5 or more + Healthcare Practitioners & Technical  54.5% --> 77.8%
# CarryAway + occupation.....................  1~3 + Construction & Extraction.................  50.9% --> 85.7%
# education + occupation.....................  Some High School + Installation Maintenance & Repair  60.7% --> 100.0%
# temperature_feels_like + occupation........  warm (80F) + Building & Grounds Cleaning & Maintenance  52.7% --> 100.0%
# expiration + occupation....................  1d + Building & Grounds Cleaning & Maintenance..  58.1% --> 87.5%
# Restaurant20To50 + occupation..............  gt8 + Healthcare Practitioners & Technical......  63.7% --> 100.0%
# ...

# %%
def get_max_rate_and_idx(grouped):
      sums = grouped['Y'].sum()
      counts = grouped['Y'].count()
      rates = sums / counts
      max_rateidx = rates.idxmax()
      max_rate = rates.max()
      return max_rate, max_rateidx

def get_column_unique_values(data, *cols):
      options_len = 0
      listed = list(itertools.chain(*cols))
      for column in listed:
            if column:
                  options_len += len(data[column].unique())
      return options_len

def iterate_combinations(basis_column, combos, dframe, print_stats=1):
      max_acceptance = 0.0
      best_combo = None
      best_options = None
      ctr = 0
      if isinstance(combos, zip):
            combos = list(combos)
      if not combos:
            combos = [basis_column]
      for combo in combos:
            if isinstance(combo, list) or isinstance(combo, tuple):
                  combo_modified = [c for c in combo if c != basis_column]
            else:
                  combo_modified = [combo] if combo != basis_column else []
            combo_modified = combo_modified + [basis_column]
            try:
                  max_rate, max_rateidx = get_max_rate_and_idx(dframe.groupby(by=combo_modified))
            except Exception as e:
                  print("error", e)
            if max_rate > max_acceptance:
                  max_acceptance = max_rate
                  best_combo = combo_modified
                  best_options = list(max_rateidx) if type(max_rateidx)!=str and type(max_rateidx)!=np.int64 else [max_rateidx]
            num = get_column_unique_values(dframe, best_combo)
            ctr += 1 * num
      if print_stats==1:
            print(f"Best Rate: {max_acceptance:.1%}\ncombo_| options_|\n{best_combo}\n{best_options}\n")
      return best_combo, best_options, max_acceptance, ctr

def get_best_combinations(dataframe, max_length=2, per_length=1):
      columns = dataframe.columns.to_list()
      columns.remove('Y')
      best_combos = {}

      for i in range(max_length):
            column_combos_dict = {}
            count = 0
            for j in range(len(columns)):
                  columns.append(columns.pop(0))
                  column_combos_dict[columns[j]] = zip(*[columns[k:] for k in range(i)])

            for combo_basis_column, combo_set in column_combos_dict.items():
                  combo, option, rate, counter = iterate_combinations(combo_basis_column, combo_set, dataframe, 0)
                  best_combos[i] = (combo, option, rate)
                  count += counter
            print(f"{i}: Combinations Iterated: {count:,}")

      return best_combos

# %%
best_combinations = get_best_combinations(coffee_house_coupons, 5)
for line in best_combinations.items():
      print(f"{line[-1][-1]:.0%}:\t\t\t\t{line[1][0]}\n\t\t\t\t\t{line[1][1]}\n")
# Out:
# 0: Combinations Iterated: 108
# 1: Combinations Iterated: 6,593
# 2: Combinations Iterated: 6,803
# 3: Combinations Iterated: 8,309
# 4: Combinations Iterated: 9,673
# 55%:				['distance_to_deal']
# 					['5 or more']
#
# 100%:				['occupation', 'distance_to_deal']
# 					['Installation Maintenance & Repair', '25 or more']
#
# 100%:				['passenger', 'weather', 'distance_to_deal']
# 					['Kid(s)', 'Rainy', '5 or more']
#
# 100%:				['destination', 'passenger', 'weather', 'distance_to_deal']
# 					['No Urgent Place', 'Kid(s)', 'Rainy', '5 or more']
#
# 100%:				['destination', 'passenger', 'weather', 'time', 'distance_to_deal']
# 					['No Urgent Place', 'Kid(s)', 'Rainy', '10AM', '5 or more']

# %%
coffee_house_coupons_without_distance = coffee_house_coupons.drop('distance_to_deal', axis=1)
best_combinations = get_best_combinations(coffee_house_coupons_without_distance, 5)
for line in best_combinations.items():
      print(f"{line[-1][-1]:.0%}:\t\t\t\t{line[1][0]}\n\t\t\t\t\t{line[1][1]}\n")
# Out:
# 0: Combinations Iterated: 63
# 1: Combinations Iterated: 2,789
# 2: Combinations Iterated: 3,414
# 3: Combinations Iterated: 3,888
# 4: Combinations Iterated: 4,352
# 53%:				['direction']
# 					['same']
#
# 100%:				['occupation', 'direction']
# 					['Architecture & Engineering', 'same']
#
# 100%:				['passenger', 'weather', 'direction']
# 					['Kid(s)', 'Rainy', 'opposite']
#
# 100%:				['destination', 'passenger', 'weather', 'direction']
# 					['No Urgent Place', 'Kid(s)', 'Rainy', 'opposite']
#
# 100%:				['destination', 'passenger', 'weather', 'time', 'direction']
# 					['No Urgent Place', 'Kid(s)', 'Rainy', '10AM', 'opposite']

# %%
def print_best_combo_record_counts(idx, cdict, filt_result):
      col_spacing = 1
      if idx==0:
            print(f"{' '*col_spacing} Options-> {' '*col_spacing}Record_Count-> {' '*col_spacing}Acceptance Rate")
      print(f"{idx}: {cdict[idx][1]} -> {' '*col_spacing}{filt_result.count()['Y']} -> {filt_result.sum()['Y'] / filt_result.count()['Y']:.2%}"
            f"\nAssociated Coupons: {filt_result['coupon'].unique()}\n")


def get_best_combo_record_counts(combinations_dict, df):
      for i in range(len(combinations_dict.keys())):
            result = df
            for subcol, subopt in zip(combinations_dict[i][0],combinations_dict[i][1]):
                  result = result[result[subcol]==subopt]
            print_best_combo_record_counts(i, combinations_dict, result)

get_best_combo_record_counts(best_combinations, coffee_house_coupons)
# Out:
#   Options->  Record_Count->  Acceptance Rate
# 0: ['same'] ->  716 -> 52.65%
# Associated Coupons: ['Coffee House']
#
# 1: ['Architecture & Engineering', 'same'] ->  6 -> 100.00%
# Associated Coupons: ['Coffee House']
#
# 2: ['Kid(s)', 'Rainy', 'opposite'] ->  5 -> 100.00%
# Associated Coupons: ['Coffee House']
#
# 3: ['No Urgent Place', 'Kid(s)', 'Rainy', 'opposite'] ->  5 -> 100.00%
# Associated Coupons: ['Coffee House']
#
# 4: ['No Urgent Place', 'Kid(s)', 'Rainy', '10AM', 'opposite'] ->  5 -> 100.00%
# Associated Coupons: ['Coffee House']

# %%
high_freq = 'CoffeeHouse in ("gt8", "4~8")'
low_freq = high_freq.replace('in', 'not in')


ch_high_freq = get_acceptance_rate(coffee_house_coupons.query(high_freq))
ch_low_freq = get_acceptance_rate(coffee_house_coupons.query(low_freq))
print(f"Proportions - Coupon Acceptance (Coffee House Coupons, Major Data)"
      f"\n\nFrequency visiting Coffee Houses"
      f"\n\tHigh:\t\t{ch_high_freq:.1%}"
      f"\n\tLow:\t\t{ch_low_freq:.1%}"
      )

ch_gt_1pm = 'CoffeeHouse not in ("never", "less1")'
isolated_pop_query = f'{over_25} and {ch_gt_1pm}'

ch_regular_over_25 = get_acceptance_rate(coffee_house_coupons.query(isolated_pop_query))
other_population = get_acceptance_rate(coffee_house_coupons.query(isolated_pop_query.replace("not in", "in")))

print(f"\n{'-'*50}"
      f"\n\nAge > 25 and CoffeeHouse Visits Per Month > 1"
      f"\n\tTrue:\t\t{ch_regular_over_25:.1%}"
      f"\n\tFalse:\t\t{other_population:.1%}"
      )

isolated_pop_query = f'{ch_gt_1pm} and {passenger_not_child} and {not_farm_fish_forest}'

ch_regular_no_child_no_fff = get_acceptance_rate(coffee_house_coupons.query(isolated_pop_query))
other_population = get_acceptance_rate(coffee_house_coupons.query(isolated_pop_query.replace("not in", "in")))

print(f"\n{'-'*50}"
      f"\n\nCoffeeHouse Visits Per Month > 1 and Passenger not Kid(s) and Occupation not FF&F"
      f"\n\tTrue:\t\t{ch_regular_no_child_no_fff:.1%}"
      f"\n\tFalse:\t\t{other_population:.1%}"
      )

isolation_1 = f'{ch_gt_1pm} and {passenger_not_child} and {not_widowed}'
isolation_2 = f'{ch_gt_1pm} and {age_under_30}'
isolation_3 = f'{cheap_resto_gt4pm} and {income_lt_50k}'
isolated_pop_query = f'{isolation_1} and {age_under_30} and {isolation_3}'

ch_regular_no_child_no_widow = get_acceptance_rate(coffee_house_coupons.query(isolation_1))
ch_regular_under_30 = get_acceptance_rate(coffee_house_coupons.query(isolation_2))
cheap_resto_regular_income_lt_50k = get_acceptance_rate(coffee_house_coupons.query(isolation_3))

anti_isolation_1 = get_acceptance_rate(coffee_house_coupons.query(isolation_1.replace("not in", "in")))
anti_isolation_2 = get_acceptance_rate(coffee_house_coupons.query(isolation_2.replace("not in", "in")))
anti_isolation_3 = get_acceptance_rate(coffee_house_coupons.query(isolation_3.replace("not in", "in")))

all_criteria_true = get_acceptance_rate(coffee_house_coupons.query(isolated_pop_query))
all_criteria_false = get_acceptance_rate(coffee_house_coupons[~(coffee_house_coupons.index.isin(coffee_house_coupons.query(isolated_pop_query).index))])

print(f"Proportions - Coupon Acceptance (CoffeeHouse Coupons, Major Data)"
      f"\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tMatch\t\tNo Match"
      f"\n\nCH Visits Per Month > 1 and Passenger not Kid(s) and Not Widowed:"
      f"\t{ch_regular_no_child_no_widow:.1%}\t\t{anti_isolation_1:.1%}"
      f"\n\nCH Visits Per Month > 1 and Age < 30:"
      f"\t\t\t\t\t\t\t\t{ch_regular_under_30:.1%}\t\t{anti_isolation_2:.1%}"
      f"\n\nCheap Resto > 4 per month and Income < 50k:"
      f"\t\t\t\t\t\t\t{cheap_resto_regular_income_lt_50k:.1%}\t\t{anti_isolation_3:.1%}"
      f"\n\nAll Above Criteria Combined:"
      f"\t\t\t\t\t\t\t\t\t\t{all_criteria_true:.1%}\t\t{all_criteria_false:.1%}"
      )
# Out:
# Proportions - Coupon Acceptance (Coffee House Coupons, Major Data)
#
# Frequency visiting Coffee Houses
# 	High:		67.3%
# 	Low:		44.6%
#
# --------------------------------------------------
#
# Age > 25 and CoffeeHouse Visits Per Month > 1
# 	True:		64.0%
# 	False:		34.9%
#
# --------------------------------------------------
#
# CoffeeHouse Visits Per Month > 1 and Passenger not Kid(s) and Occupation not FF&F
# 	True:		66.0%
# 	False:		66.7%
#
# Warning in recent call `get_acceptance_rate`: Seems to be no positive records
# Column Passed: None
# Proportions - Coupon Acceptance (CoffeeHouse Coupons, Major Data)
#
# 																	Match		No Match
#
# CH Visits Per Month > 1 and Passenger not Kid(s) and Not Widowed:	66.0%		0.0%
#
# CH Visits Per Month > 1 and Age < 30:								68.6%		33.2%
#
# Cheap Resto > 4 per month and Income < 50k:							54.7%		44.7%
#
# All Above Criteria Combined:										66.9%		48.2%

# %% [markdown]
# ## Independent Investigation - Coupon Choice: Coffee House
# ### Insights
# `Coffee House` coupons were:
# - offered `most` frequently
# - offered `most frequently` on warm `(80F)` days
# - accepted `most frequently` on warm `(80F)` days
# - accepted `less frequently (50.3%)` than the `aggregate (56.9%)`
# - accepted by `frequent coffeehouse-goers` more frequently `(67.3%)` compared to the rest of the `CoffeeHouse` coupon population `(44.6%)`
# - accepted more frequently by regular coffeehouse-goers over 25 years old `(64.0%)` compared to the rest of the `CoffeeHouse` coupon population `(34.9%)`
# - the population of regular coffeehouse-goers driving without children and who don't work in FF&F occupations does not appear indicative of acceptance `(66.0% vs 66.7%)`
# - visiting coffeehouses more than 3 times per month appears to be a good indicator of acceptance
#       - while still useful, visiting coffeehouses 1-3 times per month does not produce as strong a positive indication as the `>3 visits` population
# - age appears to be a good indicator of acceptance
#       - individuals over age 31 generally accept coffeehouse coupons less frequently
# - the `Cheap Resto > 4 per month and Income < 50k` population appears mildly indicative of acceptance `(54.7% vs 44.7%)`
# - the `Cheap Resto > 4 per month and Income < 50k` population accepts coupons slightly more frequently than the overall `CoffeeHouse` population `(54.7% vs 50.3%)`
# ### Summary
# `What do you hypothesize about drivers who accepted the coffee house coupons?`
#
# Drivers who vist coffee houses greater than 3 times per month were more likely to accept coupons for coffee houses `(67.3%)`. Drivers visiting coffee houses 1-3 times per month also accepted  more frequently `(64.8%)` than the aggregate CoffeeHouse coupon population. Warm weather (80F) appears to be slightly indicative of accepting a coupon in the aggregate population, and likewise appears to be an indicator for CoffeeHouse coupons specifically. Based on this preliminary analysis, it appears Amazon should focus marketing efforts for CoffeeHouse coupons on those individuals visiting a coffee house once per month or more. Amazon may prefer to prioritize a younger population and warmer weather. Occupation also appears to be a very strong indicator of both whether an individual receives a coupon and whether the individual accepts the coupon.
